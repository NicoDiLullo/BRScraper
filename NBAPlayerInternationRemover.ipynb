# %%
import numpy as np
import pandas as pd

# %%
players = pd.read_csv('AmericanBasketballPlayers.csv')

# %%
df = pd.DataFrame(players)

# %%
df = df[df.Nationality == 'United States']

# %%
df
# Out:
#         #              Player Pos    HT     WT   Age            Current Team  \
# 2    13.0         Bam Adebayo   C  6-10  255.0  25.0              Miami Heat
# 3    30.0        Ochai Agbaji  SF   6-5  215.0  22.0               Utah Jazz
# 6     7.0       Grayson Allen  SG   6-4  198.0  26.0         Milwaukee Bucks
# 7    31.0       Jarrett Allen   C  6-11  248.0  24.0     Cleveland Cavaliers
# 9     5.0       Kyle Anderson  PF   6-8  230.0  28.0  Minnesota Timberwolves
# ..    ...                 ...  ..   ...    ...   ...                     ...
# 521  35.0      Christian Wood  PF  6-10  223.0  26.0        Dallas Mavericks
# 522  25.0  McKinley Wright IV  PG  5-11  192.0  23.0        Dallas Mavericks
# 523  55.0        Delon Wright   G   6-5  185.0  30.0      Washington Wizards
# 524  30.0      Thaddeus Young   F   6-8  235.0  34.0         Toronto Raptors
# 525  11.0          Trae Young  PG   6-1  180.0  23.0           Atlanta Hawks
#
# ...

# %%
df.to_csv('americanBallers.csv')
